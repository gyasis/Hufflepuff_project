# %%
import pandas as pd

df = pd.read_csv("lastfantasydraft.csv")

print(list(df.columns))
#print(df.iloc[0].Description)
# Out:
# ['Unnamed: 0', 'name', 'author', 'number of ratings', 'url', 'avg_ratings', 'id', 'Num_pages', 'Verify_pages', 'Awards', 'Genre', 'Setting', 'OriginalPDate', 'VerifyDate', 'Series', 'Series-Name', 'ISBN', 'Description']

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats 
from matplotlib.ticker import MaxNLocator

def preprocessing():
    df = pd.read_csv("lastfantasydraft.csv")
    # delete unnecessary columns
    df.drop(['Unnamed: 0', 'id', 'Num_pages', 'VerifyDate'], axis = 1, inplace = True)

    df.rename(columns={'Series-Name': 'Serie_name', 'name':'Title', 'OriginalPDate':'Publishdate', 'author':'Author', 'Verify_pages': 'Num_pages'}, inplace=True)
    
    # cleaning the Title
    df['Title'] = df['Title'].str.strip()
    
    df['Serie_name'] = df['Serie_name'].replace('[\n]', '')
    
    # Calculating number of awards
    df['Awards'] = df['Awards'].str.strip('[]').replace(r'^\s*$', np.NaN, regex=True)
    df['Awards_x'] = df.Awards.str.split(',')
    df['award_count'] = df['Awards_x'].str.len()
    df['award_count'] = df['award_count'].fillna(0).astype(int)
    df = df.drop(['Awards_x'], axis= 1)
    
    # cleaning series column
    #df['Series'] = df['Series'].str.strip('[]')
    
    # cleaning setting column
    df['Setting'] = df['Setting'].str.strip('[]')

    # Cleaning author column from paranthesis text
    df['Author'] = df.Author.str.replace(r" \(.*Goodreads Author\)","")

    # cleaning number of ratings
    df.rename(columns={'number of ratings': 'number_of_ratings'}, inplace=True)
    df['number_of_ratings'] = df['number_of_ratings'].str.replace('[,]',"").str.replace('[^0-9]',"0").fillna(0).astype(int)

    # cleaning avg_rat
    df['avg_ratings'] = df.avg_ratings.str.replace('[^0-9.]',"")
    df.loc[df['avg_ratings'] == '.', 'avg_ratings'] = np.NaN
    df['avg_ratings'] = df['avg_ratings'].replace(r'^\s*$', np.NaN, regex=True).astype(float)
    
    # cleaning Genre
    df['Genre'] = df['Genre'].str.strip('[]')
    
    # cleaning pages
    df['Num_pages'] = df['Num_pages'].astype(str)
    df['Num_pages'] = df.Num_pages.str.replace('[^0-9]',"")
    for i in df.index:
        if len(df.iloc[i]['Num_pages']) >= 5 or len(df.iloc[i]['Num_pages']) <= 1:
            df.at[i, 'Num_pages'] = np.NaN
    df['Num_pages'] = df['Num_pages'].replace(r'^\s*$', np.NaN, regex=True)
    df['Num_pages'] = pd.to_numeric(df['Num_pages'])
    
    # cleaning publish year
    df.rename(columns={' Publishdate': 'Publishdate'}, inplace=True)
    df['Publishdate'] = df.Publishdate.str.replace('[^0-9-]',"")
    df['original_publish_year'] = df['Publishdate'].replace(r'^\s*$', np.NaN, regex=True).str[-4:]
    df = df.drop(['Publishdate'], axis= 1)
    
    # Calculating normalized ratings
    df['minmax_norm_ratings'] = 1 + (df['avg_ratings'] - df.avg_ratings.min()) / (df.avg_ratings.max()-df.avg_ratings.min()) *9
    df['mean_norm_ratings'] = 1 + ((df['avg_ratings'] - df.avg_ratings.mean()) / (df.avg_ratings.max()-df.avg_ratings.min())) *9

    # delete last 7 rows    
    df.drop(df.tail(7).index, inplace = True) 

    # Just for CSV to show data
    #df.rename(columns={'url': 'URL', 'avg_ratings':'Average rating', 'original_publish_year':'Publishingdate', 'number_of_ratings':'Number of ratings', 'Num_pages': 'Number of pages', 'award_count': 'Number of awards'}, inplace=True)
    #df.to_csv('Data_Show.csv')
    
    df.to_csv('Data_graphs.csv')
    return df


preprocessing()
# Out:
#                                                   Title               Author  \
# 0        A Game of Thrones (A Song of Ice and Fire, #1)   George R.R. Martin
# 1     J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...       J.R.R. Tolkien
# 2     The Name of the Wind (The Kingkiller Chronicle...     Patrick Rothfuss
# 3         The Way of Kings (The Stormlight Archive, #1)    Brandon Sanderson
# 4     The Chronicles of Narnia (Chronicles of Narnia...           C.S. Lewis
# ...                                                 ...                  ...
# 1088        Sora's Quest (The Cat's Eye Chronicles, #1)       T.L. Shreffler
# 1089                     Dies the Fire (Emberverse, #1)        S.M. Stirling
# 1090  To Journey in the Year of the Tiger (Upper Kin...  H. Leighton Dickson
# 1091    To Walk in the Way of Lions (Upper Kingdom, #2)  H. Leighton Dickson
# 1092  Shroud of Darkness (The Chronicles of Celadmor...         C.S. Woolley
#
#       number_of_ratings                                                url  \
# 0               2049108  https://www.goodreads.com//book/show/13496.A_G...
# 1                112537  https://www.goodreads.com//book/show/30.J_R_R_...
# 2                740343  https://www.goodreads.com//book/show/186074.Th...
# 3                320338  https://www.goodreads.com//book/show/7235533-t...
# 4                533551  https://www.goodreads.com//book/show/11127.The...
# ...                 ...                                                ...
# 1088               5136  https://www.goodreads.com//book/show/13606393-...
# 1089              15205  https://www.goodreads.com//book/show/116445.Di...
# 1090                400  https://www.goodreads.com//book/show/21563710-...
# 1091                190  https://www.goodreads.com//book/show/21564028-...
# 1092                  6  https://www.goodreads.com//book/show/17883588-...
#
#       avg_ratings  Num_pages  \
# 0            4.45      835.0
# 1            4.60     1728.0
# 2            4.52      662.0
# 3            4.62     1007.0
# 4            4.26      767.0
# ...           ...        ...
# 1088         3.99      250.0
# 1089         3.93      573.0
# 1090         3.98      350.0
# 1091         4.26      356.0
# 1092         4.83      379.0
#
#                                                  Awards  \
# 0     'Nebula Award Nominee for Best Novel (1997)', ...
# 1                                                   NaN
# 2     'Locus Award Nominee for Best First Novel and ...
# 3     'Locus Award Nominee for Best Fantasy Novel (2...
# 4                                                   NaN
# ...                                                 ...
# 1088                                       'SKoW Award'
# 1089                                                NaN
# 1090                                                NaN
# 1091                                                NaN
# 1092                                                NaN
#
#                                                   Genre  \
# 0     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...
# 1     'Fantasy', 'Fiction', 'Classics', 'Adventure',...
# 2     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...
# 3     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...
# 4     'Fantasy', 'Classics', 'Fiction', 'Young Adult...
# ...                                                 ...
# 1088  'Fantasy', 'Young Adult', 'Fantasy', 'Magic', ...
# 1089  'Science Fiction', 'Fantasy', 'Apocalyptic', '...
# 1090  'Fantasy', 'Fiction', 'Fantasy', 'High Fantasy...
# 1091  'Fantasy', 'Business', 'Amazon', 'Science Fict...
# 1092
#
#                           Setting  Series  \
# 0     'The Lands of Ice and Fire'    True
# 1                  'Middle-earth'    True
# 2                                    True
# 3                        'Roshar'    True
# 4               'London, England'    True
# ...                           ...     ...
# 1088                                 True
# 1089                     'Oregon'    True
# 1090                                 True
# 1091                                 True
# 1092                                 True
#
#                                              Serie_name  \
# 0              \nSeries\n\nA Song of Ice and Fire #1 \n
# 1     \nSeries\n\nThe Lord of the Rings #0-3, Middle...
# 2            \nSeries\n\nThe Kingkiller Chronicle #1 \n
# 3     \nSeries\n\nThe Stormlight Archive #1, The Cos...
# 4     \nSeries\n\nThe Chronicles of Narnia (Publicat...
# ...                                                 ...
# 1088         \nSeries\n\nThe Cat's Eye Chronicles #1 \n
# 1089  \nSeries\n\nEmberverse #1, The Change (Emberve...
# 1090                    \nSeries\n\nUpper Kingdom #1 \n
# 1091                    \nSeries\n\nUpper Kingdom #2 \n
# 1092      \nSeries\n\nThe Chronicles of Celadmore #4 \n
#
#                                                    ISBN  \
# 0     \nISBN\n\n                  0553588486\n      ...
# 1     \nISBN\n\n                  0345538374\n      ...
# 2     \nISBN\n\n                  075640407X\n      ...
# 3     \nISBN\n\n                  0765326353\n      ...
# 4                                                   NaN
# ...                                                 ...
# 1088  \nISBN\n\n                  0985166339\n      ...
# 1089  \nISBN\n\n                  0451460413\n      ...
# 1090                                                NaN
# 1091                                                NaN
# 1092                          \nISBN13\n9781301367474\n
#
#                                             Description  award_count  \
# 0     [<div class="readable stacked" id="description...            4
# 1     [<div class="readable stacked" id="description...            0
# 2     [<div class="readable stacked" id="description...            8
# 3     [<div class="readable stacked" id="description...            4
# 4     [<div class="readable stacked" id="description...            0
# ...                                                 ...          ...
# 1088  [<div class="readable stacked" id="description...            1
# 1089  [<div class="readable stacked" id="description...            0
# 1090  [<div class="readable stacked" id="description...            0
# 1091  [<div class="readable stacked" id="description...            0
# 1092  [<div class="readable stacked" id="description...            0
#
#      original_publish_year  minmax_norm_ratings  mean_norm_ratings
# 0                     1996             8.088496           2.407440
# 1                     1955             8.685841           3.004785
# 2                     2007             8.367257           2.686201
# 3                      NaN             8.765487           3.084431
# 4                     1956             7.331858           1.650803
# ...                    ...                  ...                ...
# 1088                   NaN             6.256637           0.575581
# 1089                  2004             6.017699           0.336643
# 1090                   NaN             6.216814           0.535758
# 1091                  2012             7.331858           1.650803
# 1092                   NaN             9.601770           3.920714
#
# [1093 rows x 17 columns]

# %%
df = preprocessing()
display(df.isnull().sum())
# Out:
# Title                      0
# Author                     0
# number_of_ratings          0
# url                        0
# avg_ratings               30
# Num_pages                 37
# Awards                   682
# Genre                      0
# Setting                    0
# Series                     0
# Series-Name              141
# ISBN                     173
# Description                0
# award_count                0
# original_publish_year    399
# minmax_norm_ratings       30
# mean_norm_ratings         30
# dtype: int64

# %%
dg = df.loc[df["Author"] == "George R.R. Martin"].sort_values(by=['avg_ratings'], ascending= False).head(1)
dg
# Out:
#                                                  Title              Author  \
# 566  A Song of Ice and Fire (A Song of Ice and Fire...  George R.R. Martin
#
#      number_of_ratings                                                url  \
# 566              54708  https://www.goodreads.com//book/show/12177850-...
#
#      avg_ratings  Num_pages Awards  \
# 566         4.55     5216.0    NaN
#
#                                                  Genre Setting  Series  \
# 566  'Fantasy', 'Fiction', 'Science Fiction Fantasy...            True
#
#                                     Series-Name  \
# 566  \nSeries\n\nA Song of Ice and Fire #1-5 \n
#
#                                                   ISBN  \
# 566  \nISBN\n\n                  1780484259\n      ...
#
#                                            Description  award_count  \
# 566  [<div class="readable stacked" id="description...            0
#
#     original_publish_year  minmax_norm_ratings  mean_norm_ratings
# 566                  2000             8.486726            2.80567

# %%
dg.Title
# Out:
# 566    A Song of Ice and Fire (A Song of Ice and Fire...
# Name: Title, dtype: object

# %%
preprocessing().dtypes
# Out:
# Title                     object
# Author                    object
# number_of_ratings          int64
# url                       object
# avg_ratings              float64
# Num_pages                float64
# Awards                    object
# Genre                     object
# Setting                   object
# Series                      bool
# Series-Name               object
# ISBN                      object
# Description               object
# award_count                int64
# original_publish_year     object
# minmax_norm_ratings      float64
# mean_norm_ratings        float64
# dtype: object

# %%
# Analyse exercise from day 1

def analyse_highest_book(df, a):
    df_a = df.dropna(subset= ['minmax_norm_ratings'])
    dp = df_a.groupby(df_a.original_publish_year).agg({'minmax_norm_ratings': np.mean})
    dp = dp.rename(columns={'minmax_norm_ratings': 'minmax_norm_ratings_mean'})
    author_group = df.loc[df['Author'] == a]
    book_max_rating = author_group.iloc[author_group['minmax_norm_ratings'].argmax()]['Title']
        
    print(book_max_rating)
    return dp

print(analyse_highest_book(preprocessing(), 'J.R.R. Tolkien'))
# Out:
# J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings
#                        minmax_norm_ratings_mean
# original_publish_year
# -750                                   5.778761
# -800                                   5.380531
# 009-                                   7.331858
# 012-                                   8.287611
# 013-                                   8.407080
# ...                                         ...
# 2018                                   7.338146
# 2019                                   7.530973
# 2020                                   8.373894
# 2021                                   5.977876
# 999-                                   7.491150
#
# [93 rows x 1 columns]

# %%
# 1. Create a 2D scatterplot with pages on the x-axis and num_ratings on the y-axis.

df_s = preprocessing().dropna(subset=['Num_pages', 'number_of_ratings'])
df_s['Num_pages'] = df_s['Num_pages'].astype(int)
df_s['number_of_ratings'] = df_s['number_of_ratings'].astype(int)
_= sns.scatterplot(data=df_s, x="Num_pages", y="number_of_ratings")
plt.title('Scatterplot of number of pages to number of ratings', size= 12);
_= plt.xlabel('Number of pages')
_= plt.ylabel('Number of ratings')
plt.show()

# %%
#Number of pages vs awards

df_s = preprocessing().dropna(subset=['Num_pages', 'award_count'])
df_s['Num_pages'] = df_s['Num_pages'].astype(int)
df_s['award_count'] = df_s['award_count'].astype(int)
_= sns.scatterplot(data=df_s, x="Num_pages", y="award_count")
plt.title('Scatterplot of number of pages to number of awards', size= 12);
_=plt.xlabel('Number of pages')
_=plt.ylabel('Number of awards')
plt.show()

# %%
#Subplot

plt.figure(figsize=(20,10))
x1  = df_s['Num_pages'].astype(int)
x2 = df_s['Num_pages'].astype(int)

y1 = df_s['number_of_ratings'].astype(int)
y2 = df_s['award_count'].astype(int)

plt.subplot(1,2,1)
plt.scatter(x1, y1, color='blue')
plt.xlabel("Number of pages")
plt.ylabel("Number of ratings")

plt.subplot(1,2,2)
plt.scatter(x2, y2, color='red')
plt.xlabel("Number of pages")
plt.ylabel("Number of awards")

plt.tight_layout()
plt.show()

# %%
# 2. Can you compute numerically the correlation coefficient of these two columns?
# calculate correlation between pages and number of ratings

column_1 = preprocessing()["Num_pages"]
column_2 = preprocessing()["number of ratings"]
correlation = column_1.corr(column_2) 
print(correlation)
# Out:
# -0.017251076391944318

# %%
# 3. Visualise the avg_rating distribution.
# boxplot and histogram for average rating

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)}, figsize=(10,7))

mean=preprocessing()['avg_ratings'].mean()
median=preprocessing()['avg_ratings'].median()

sns.boxplot(preprocessing()["avg_ratings"], ax=ax_box, color = 'aqua')
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.xaxis.set_ticks_position('top') 

sns.histplot(preprocessing()["avg_ratings"], ax=ax_hist, color = 'aqua', edgecolor = 'black')
ax_hist.axvline(mean, color='r', linestyle='--')
ax_hist.axvline(median, color='g', linestyle='-')

plt.legend({'Mean':mean,'Median':median})

ax_box.set(title= 'Average Rating', xlabel='')
ax_hist.set(xlabel='Average Rating', ylabel='Number of books')
plt.show()
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 4. Visualise the minmax_norm_rating distribution.
#    boxplot and histogram for min-max normalized ratings

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)}, figsize=(10,7))


sns.boxplot(preprocessing()["minmax_norm_ratings"], ax=ax_box, color = 'aqua')
ax_box.xaxis.set_ticks_position('top') 
sns.histplot(preprocessing()["minmax_norm_ratings"], ax=ax_hist, color = 'aqua', edgecolor = 'black')

ax_box.set(title= 'Min-Max Normalized Rating', xlabel='')
ax_hist.set(xlabel='Min-Max Normalized Rating', ylabel='')
plt.show()
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# 5. Visualise the mean_norm_rating distribution.
#    boxplot and histogram for mean normalized ratings

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)}, figsize=(10,7))


sns.boxplot(preprocessing()["mean_norm_ratings"], ax=ax_box, color= 'purple')
ax_box.xaxis.set_ticks_position('top') 
sns.distplot(preprocessing()["mean_norm_ratings"], ax=ax_hist,color='purple')


ax_box.set(title= 'Mean Normalized Rating', xlabel='')
ax_hist.set(xlabel='Mean Normalized Rating', ylabel='')
plt.xlim([0,10])
plt.show()
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 6 Create one graph that represents in the same figure both minmax_norm_rating and mean_norm_ratingdistributions.

#a = preprocessing()
#minmax_mean = a[['minmax_norm_ratings', 'mean_norm_ratings']]
#sns.relplot(data=minmax_mean); 

#pawas
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set_palette(['green', 'purple'])
plt.figure(figsize=(12, 10))
a = preprocessing()
minmax_mean = a[['minmax_norm_ratings', 'mean_norm_ratings']]
plt.subplot(2,1,1)
ax=sns.scatterplot(data=minmax_mean);
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1));
ax.set(xlabel='book number', ylabel='min_max normal rating');
plt.subplot(2,1,2)
ax=sns.lineplot(data=minmax_mean);
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1));
ax.set(xlabel='book number', ylabel='min_max normal rating');

# %%
# 7 What is the best fit in terms of a distribution (normal, chi-squared...) to represent each of those graphs?

# %%
# %matplotlib inline

import warnings
import numpy as np
import pandas as pd
import scipy.stats as st
#import statsmodels as sm
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

w = preprocessing()
data = w["avg_ratings"].dropna()

matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# Create models from data
def best_fit_distribution(data, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [        
        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
    ]

    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

# %%
def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# %%
# Load data from statsmodels datasets
#data = pd.Series(sm.datasets.elnino.load_pandas().data.set_index('YEAR').values.ravel())

# Plot for comparison
plt.figure(figsize=(12,8))
ax = data.plot(kind='hist', bins=50, alpha=0.5, density=True)
#sns.distplot(pdf, fit=norm, hist=True)

# Save plot limits
dataYLim = ax.get_ylim()

# Find best fit distribution
best_fit_name, best_fit_params = best_fit_distribution(data, 200, ax)
best_dist = getattr(st, best_fit_name)

# Update plots
ax.set_ylim(dataYLim)
ax.set_title(u'Average Rating\n All Fitted Distributions')
ax.set_xlabel(u'Average Rating')
ax.set_ylabel('Frequency')

# Make PDF with best params 
pdf = make_pdf(best_dist, best_fit_params)

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True)

data.plot(kind='hist', bins=50, alpha=0.5, label='Data', legend=True,density=True, ax=ax)

param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
dist_str = '{}({})'.format(best_fit_name, param_str)

ax.set_title(u'Average Rating  \n' + dist_str)
ax.set_xlabel(u'Average Rating')
ax.set_ylabel('Frequency')
plt.legend()
plt.show()

# %%
# 8 Visualize the awards distribution in a boxplot and aggregtated bars. 
#   Decide which of these representations gives us more information and in which cases they should be used.

sns.set(rc={'figure.figsize':(11.7,5.0)})

_= sns.boxplot(x=preprocessing()["award_count"],color='aqua', showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"red", 
                       "markeredgecolor":"white",
                      "markersize":"10"}, showfliers = True)
_= plt.xlabel('Number of awards');

#for row in preprocessing().itertuples():
#    val = row.award_count
#    if val > 10: #or val < outlier_bottom_lim[month]:
#        if row.Index in preprocessing().loc[preprocessing().groupby('award_count')['number_of_ratings'].idxmax()].index:
#            plt.text(val, - 0.3, f'{row.Title}', ha='left', va='center', rotation=65, size=15)

# %%
# 8 Visualize the awards distribution in a boxplot and aggregtated bars. 
#   Decide which of these representations gives us more information and in which cases they should be used

from matplotlib.ticker import MaxNLocator

dz = preprocessing()['award_count'].value_counts()
dw= dz.sort_index()
dw = pd.DataFrame(dw)
dw.reset_index(inplace=True)
dw = dw.rename(columns = {'index':'award_count', 'award_count': 'num_books'})

sns.set_context('talk')
sns.set_style('whitegrid')

plt.figure(figsize=(14, 8))
ax= sns.barplot(y=dw['num_books'],x=dw["award_count"])
ax.set_yscale("log")
for p in ax.patches:
    ax.annotate(format(int(p.get_height())), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')


ax= plt.xlabel('Number of awards')
ax= plt.ylabel('Number of books')

# %%
df= preprocessing()
df_sorted = df.sort_values(by='award_count', ascending=False).head(10)
df_sorted['Title']

print(df.iloc[360])
# Out:
# Title                              The Hunger Games (The Hunger Games, #1)
# Author                                                     Suzanne Collins
# number_of_ratings                                                  6542508
# url                      https://www.goodreads.com//book/show/2767052-t...
# avg_ratings                                                           4.33
# Num_pages                                                              374
# Awards                   'Locus Award Nominee for Best Young Adult Book...
# Genre                    'Young Adult', 'Fiction', 'Science Fiction', '...
# Setting                    'District 12, Panem', 'Capitol, Panem', 'Panem'
# Series                                                                True
# Series-Name                             \nSeries\n\nThe Hunger Games #1 \n
# ISBN                     \nISBN\n\n                  0439023483\n      ...
# Description              [<div class="readable stacked" id="description...
# award_count                                                             41
# original_publish_year                                                  NaN
# minmax_norm_ratings                                                7.61062
# mean_norm_ratings                                                  1.92956
# Name: 360, dtype: object

# %%
# 9 Now, make a simple plot to visualise the ratings w.r.t. the years!



new_df_pawas = preprocessing().dropna(subset=['number_of_ratings', 'original_publish_year'])
new_df_pawas.sort_values(by=['original_publish_year'],inplace=True)
#new_df_pawas

#d=new_df_pawas.to_dict
df55=pd.DataFrame()
y=list(new_df_pawas['original_publish_year'])
r=list(new_df_pawas['number_of_ratings'])
df55['year']=y
df55['number_of_ratings']=r
#df55.year
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set_palette(['purple'])
plt.figure(figsize=(19, 9))
plt.subplot(2,1,1)
new_plt2=sns.scatterplot(y=df55["number_of_ratings"],x=df55["year"],s=50)
#new_plt2=sns.regplot(data=df55,y="number_of_ratings",x="year")
#new_plt2.set(xticks=df55.year[0:-2])
plt.xlabel("Year",size = 30)
plt.ylabel("Number of ratings",size = 30)
new_plt2.tick_params(labelsize=11,rotation=60)
#df55.year[0::100]

# %%
tt= preprocessing()["original_publish_year"].sort_values()

# %%
# 10. Make a scatterplot to represent minmax_norm_ratings in function of the number of awards won by the book.

#sns.set(rc={'figure.figsize':(8,5.5)})
#pawas
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set_palette(['purple'])
plt.figure(figsize=(20, 11))
plt.subplot(2,1,2)
_= sns.lineplot(data=preprocessing(), x="minmax_norm_ratings", y="award_count")
_= plt.ylabel("Number of awards")
_= plt.xlabel("Min-Max normalized ratings")
plt.subplot(2,1,1)
_= sns.regplot(data=preprocessing(), x="minmax_norm_ratings", y="award_count")
_= plt.ylabel("Number of awards")
_= plt.xlabel("Min-Max normalized ratings")

# %%
# Check if this is interesting

#sns.set(rc={'figure.figsize':(8,5.5)})
#pawas
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set_palette(['purple'])
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
_= sns.regplot(data=preprocessing(), y="number_of_ratings", x="award_count")
_= plt.ylabel("Number of awards")
_= plt.xlabel("Number of ratings")
plt.subplot(2,1,2)
_= sns.lineplot(data=preprocessing(), y="number_of_ratings", x="award_count")
_= plt.ylabel("Number of awards")
_= plt.xlabel("Number of ratings")

# %% [markdown]
# From here just for backup

# %%
plt.figure(figsize=(14, 8))
_= sns.boxplot(x=preprocessing()["avg_ratings"],color='blue', showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"red", 
                       "markeredgecolor":"white",
                      "markersize":"10"})
_= plt.xlabel('Average Rating')

# %%
plt.figure(figsize=(14, 10))
_= sns.boxplot(x=preprocessing()["minmax_norm_ratings"],color='blue', showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"red", 
                       "markeredgecolor":"white",
                      "markersize":"10"})
_= plt.xlabel('Min-Max Normal Distribution')

# %%
plt.figure(figsize=(15, 15))
_= sns.displot(preprocessing(), x="minmax_norm_ratings")
_= plt.ylabel("Books")
_= plt.xlabel('Min-Max')

# %%
N = 150
data = np.linspace(0, N, N)

plt.plot(data)

plt.xticks(range(N)) # add loads of ticks
plt.grid()
plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_xticklabels()
maxsize = max([t.get_window_extent().width for t in tl])
m = 0.2 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]
#plt.gcf().subplots_adjust(left=margin, right=1.-margin)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
#

# %%
df.original_publish_year
# Out:
# 0       1996
# 1       1955
# 2       2007
# 3        NaN
# 4       1956
#         ...
# 1086     NaN
# 1087     NaN
# 1088     NaN
# 1089    2004
# 1090     NaN
# Name: original_publish_year, Length: 1091, dtype: object

# %%
bins = pd.IntervalIndex.from_tuples([(0, 1800), (1801, 1900), (1901, 1910), (1911, 1920), (1921, 1930), (1931, 1940), (1941, 1950), (1951, 1960), (1961, 1970), (1971, 1980), (1981, 1990), (1991, 2000), (2001, 2010), (2011, 2020)])
print(bins)
df2 = df.dropna(subset=['original_publish_year'])
df2["yeargrp"] = pd.cut(df['original_publish_year'], bins)
print(df2)
#dp = df2.groupby(df2.yeargrp)
#dp = dp.rename(columns={'minmax_norm_ratings': 'minmax_norm_ratings_mean'})
# Out:
# IntervalIndex([(0, 1800], (1801, 1900], (1901, 1910], (1911, 1920], (1921, 1930] ... (1971, 1980], (1981, 1990], (1991, 2000], (2001, 2010], (2011, 2020]],
#               closed='right',
#               dtype='interval[int64]')
#       Unnamed: 0                                              Title  \
# 0            0.0     A Game of Thrones (A Song of Ice and Fire, #1)
# 1            1.0  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 2            2.0  The Name of the Wind (The Kingkiller Chronicle...
# 4            4.0  The Chronicles of Narnia (Chronicles of Narnia...
# 5            5.0       The Eye of the World (The Wheel of Time, #1)
# ...          ...                                                ...
# 1075      1075.0  Attrition: the First Act of Penance (Three Act...
# 1078      1078.0                         Sands (Sharani series, #1)
# 1079      1079.0                               The Devil's Advocate
# 1085      1085.0         First Magyc (Guardians of the Path Book 1)
# 1089      1089.0                     Dies the Fire (Emberverse, #1)
#
#                   Author  number_of_ratings  \
# 0     George R.R. Martin            2047731
# 1         J.R.R. Tolkien             112472
# 2      Patrick Rothfuss              739671
# 4             C.S. Lewis             533099
# 5          Robert Jordan             402710
# ...                  ...                ...
# 1075         S.G. Night                 752
# 1078   Kevin L. Nielsen                 608
# 1079       L.E.  Parker                  15
# 1085  Nicole DragonBeck                  47
# 1089       S.M. Stirling              15201
#
#                                                     url  avg_ratings      id  \
# 0     https://www.goodreads.com//book/show/13496.A_G...         4.45     0.0
# 1     https://www.goodreads.com//book/show/30.J_R_R_...         4.60     1.0
# 2     https://www.goodreads.com//book/show/186074.Th...         4.52     2.0
# 4     https://www.goodreads.com//book/show/11127.The...         4.26     4.0
# 5     https://www.goodreads.com//book/show/228665.Th...         4.17     5.0
# ...                                                 ...          ...     ...
# 1075  https://www.goodreads.com//book/show/18400770-...         4.12  1075.0
# 1078  https://www.goodreads.com//book/show/25973595-...         3.80  1078.0
# 1079  https://www.goodreads.com//book/show/33260689-...         3.53  1079.0
# 1085  https://www.goodreads.com//book/show/25434542-...         4.26  1085.0
# 1089  https://www.goodreads.com//book/show/116445.Di...         3.93  1089.0
#
#       Num_pages                                             Awards  \
# 0         835.0  'Nebula Award Nominee for Best Novel (1997)', ...
# 1           NaN                                                NaN
# 2         662.0  'Locus Award Nominee for Best First Novel and ...
# 4           NaN                                                NaN
# 5         814.0  'Locus Award Nominee for Best Fantasy Book (19...
# ...         ...                                                ...
# 1075        NaN                     "Readers' Favorite Book Award"
# 1078      283.0                                                NaN
# 1079      696.0                                                NaN
# 1085      321.0                                                NaN
# 1089      573.0                                                NaN
#
#                                                   Genre  award_count  \
# 0     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            4
# 1     'Fantasy', 'Fiction', 'Classics', 'Adventure',...            0
# 2     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            8
# 4     'Fantasy', 'Classics', 'Fiction', 'Young Adult...            0
# 5     'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            1
# ...                                                 ...          ...
# 1075  'Fantasy', 'Fantasy', 'High Fantasy', 'Fantasy...            1
# 1078  'Fantasy', 'Young Adult', 'Fantasy', 'Magic', ...            0
# 1079                 'Fantasy', 'Fantasy', 'Paranormal'            0
# 1085                                          'Fantasy'            0
# 1089  'Science Fiction', 'Fantasy', 'Apocalyptic', '...            0
#
#      original_publish_year  minmax_norm_ratings  mean_norm_ratings yeargrp
# 0                     1996             8.088496           2.410433     NaN
# 1                     1955             8.685841           3.007778     NaN
# 2                     2007             8.367257           2.689194     NaN
# 4                     1956             7.331858           1.653795     NaN
# 5                     1990             6.973451           1.295388     NaN
# ...                    ...                  ...                ...     ...
# 1075                  2013             6.774336           1.096273     NaN
# 1078                  2015             5.500000          -0.178063     NaN
# 1079                  2016             4.424779          -1.253284     NaN
# 1085                  2015             7.331858           1.653795     NaN
# 1089                  2004             6.017699           0.339636     NaN
#
# [692 rows x 15 columns]
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df['original_publish_year'] = pd.to_numeric(df['original_publish_year'])

# %%
# 9 Now, make a simple plot to visualise the ratings w.r.t. the years!



new_df_pawas = preprocessing().dropna(subset=['number_of_ratings', 'original_publish_year'])
new_df_pawas.sort_values(by=['original_publish_year'],inplace=True)
#new_df_pawas

#d=new_df_pawas.to_dict
df55=pd.DataFrame()
y=list(new_df_pawas['original_publish_year'])
r=list(new_df_pawas['number_of_ratings'])
df55['year']=y
df55['number_of_ratings']=r
#df55.year
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set_palette(['purple'])
plt.figure(figsize=(19, 9))
plt.subplot(2,1,1)
new_plt2=sns.scatterplot(y=df55["number_of_ratings"],x=df55["year"],s=50)
#new_plt2=sns.regplot(data=df55,y="number_of_ratings",x="year")
#new_plt2.set(xticks=df55.year[0:-2])
plt.xlabel("Year",size = 30)
plt.ylabel("Number of ratings",size = 30)
new_plt2.tick_params(labelsize=11,rotation=60)
#df55.year[0::100]
