# %%
import pandas as pd
import numpy as np

def preprocessing():
    df = pd.read_csv("example.csv")
    
    # Calculating number of awards
    df['Awards'] = df['Awards'].str.strip('[]')
    df['Awards'] = df['Awards'].replace(r'^\s*$', np.NaN, regex=True)
    df['Awards_x'] = df.Awards.str.split(',')
    df['award_count'] = df['Awards_x'].str.len()
    df['award_count'] = df['award_count'].fillna(0)
    df['award_count'] = df['award_count'].astype(int)
    df = df.drop(['Awards_x'], axis= 1)
    
    # Calculating normalized ratings
    df['minmax_norm_ratings'] = 1 + (df['avg_rat'] - df.avg_rat.min()) / (df.avg_rat.max()-df.avg_rat.min()) *9
    df['mean_norm_ratings'] = 1 + (df['avg_rat'] - df.avg_rat.mean()) / (df.avg_rat.max()-df.avg_rat.min()) *9
    
    return df

preprocessing()
# Out:
#                                                 name  \
# 0     A Game of Thrones (A Song of Ice and Fire, #1)
# 1    J.R.R. Tolkien 4-Book Boxed Set: The Hobbit ...
# 2    The Name of the Wind (The Kingkiller Chronic...
# 3      The Way of Kings (The Stormlight Archive, #1)
# 4    The Chronicles of Narnia (Chronicles of Narn...
# 5       The Eye of the World (The Wheel of Time, #1)
# 6                    The Final Empire (Mistborn, #1)
# 7       His Dark Materials (His Dark Materials #1-3)
# 8                 Eragon (The Inheritance Cycle, #1)
# 9        Assassin's Apprentice (Farseer Trilogy, #1)
#
#                                    author number of ratings  \
# 0                      George R.R. Martin         2,046,885
# 1                          J.R.R. Tolkien           112,425
# 2     Patrick Rothfuss (Goodreads Author)           739,299
# 3    Brandon Sanderson (Goodreads Author)           319,614
# 4                              C.S. Lewis           532,855
# 5                           Robert Jordan           402,524
# 6    Brandon Sanderson (Goodreads Author)           419,345
# 7                          Philip Pullman           147,381
# 8  Christopher Paolini (Goodreads Author)         1,470,169
# 9           Robin Hobb (Goodreads Author)           242,007
#
#                                                  url  avg_rat  \
# 0  https://www.goodreads.com//book/show/13496.A_G...     4.45
# 1  https://www.goodreads.com//book/show/30.J_R_R_...     4.60
# 2  https://www.goodreads.com//book/show/186074.Th...     4.52
# 3  https://www.goodreads.com//book/show/7235533-t...     4.62
# 4  https://www.goodreads.com//book/show/11127.The...     4.26
# 5  https://www.goodreads.com//book/show/228665.Th...     4.17
# 6  https://www.goodreads.com//book/show/68428.The...     4.44
# 7  https://www.goodreads.com//book/show/18116.His...     4.25
# 8  https://www.goodreads.com//book/show/113436.Er...     3.91
# 9  https://www.goodreads.com//book/show/77197.Ass...     4.15
#
#                        Num_pages  \
# 0                      835 pages
# 1  Hobbit Movie Tie-in Boxed set
# 2                      662 pages
# 3                     1007 pages
# 4                Reissue Edition
# 5                      814 pages
# 6                      544 pages
# 7                     1088 pages
# 8                      503 pages
# 9                      435 pages
#
#                                               Awards  \
# 0  'Nebula Award Nominee for Best Novel (1997)', ...
# 1                                                NaN
# 2  'Locus Award Nominee for Best First Novel and ...
# 3  'Locus Award Nominee for Best Fantasy Novel (2...
# 4                                                NaN
# 5  'Locus Award Nominee for Best Fantasy Book (19...
# 6  'Tähtifantasia Award Nominee (2018)', 'Prix El...
# 7  'Literaturpreis der Jury der jungen Leser for ...
# 8  "Book Sense Book of the Year Award for Childre...
# 9  'Locus Award Nominee for Fantasy (1996)', 'Bri...
#
#                                                Genre  \
# 0  ['Fantasy', 'Fiction', 'Fantasy', 'Epic Fantas...
# 1  ['Fantasy', 'Fiction', 'Classics', 'Adventure'...
# 2  ['Fantasy', 'Fiction', 'Fantasy', 'Epic Fantas...
# 3  ['Fantasy', 'Fiction', 'Fantasy', 'Epic Fantas...
# 4  ['Fantasy', 'Classics', 'Fiction', 'Young Adul...
# 5  ['Fantasy', 'Fiction', 'Fantasy', 'Epic Fantas...
# 6  ['Fantasy', 'Fiction', 'Fantasy', 'High Fantas...
# 7  ['Fantasy', 'Young Adult', 'Fiction', 'Childre...
# 8  ['Fantasy', 'Young Adult', 'Fiction', 'Fantasy...
# 9  ['Fantasy', 'Fiction', 'Fantasy', 'Epic Fantas...
#
#                                          Publishdate  award_count  \
# 0  [<nobr class="greyText">\n              (first...            4
# 1  [<nobr class="greyText">\n              (first...            0
# 2  [<nobr class="greyText">\n              (first...            8
# 3                                                 []            4
# 4  [<nobr class="greyText">\n              (first...            0
# 5  [<nobr class="greyText">\n              (first...            1
# 6  [<nobr class="greyText">\n              (first...            2
# 7  [<nobr class="greyText">\n              (first...            1
# 8  [<nobr class="greyText">\n              (first...           20
# 9  [<nobr class="greyText">\n              (first...            3
#
#    minmax_norm_ratings  mean_norm_ratings
# 0             7.845070           2.432394
# 1             9.746479           4.333803
# 2             8.732394           3.319718
# 3            10.000000           4.587324
# 4             5.436620           0.023944
# 5             4.295775          -1.116901
# 6             7.718310           2.305634
# 7             5.309859          -0.102817
# 8             1.000000          -4.412676
# 9             4.042254          -1.370423

# %%
import pandas as pd
import numpy as np

def preprocessing():
    #df = pd.read_csv(csv_path)

    df = pd.DataFrame([
      { 'author': 'abc', 'avg_ratings': 4.1, 'awards': 'Hello, Hello, Hello', 'original_publish_year': 2010},
      { 'author': 'def', 'avg_ratings': 2.5, 'awards': 'Hello, Hello', 'original_publish_year': 2012},
      { 'author': 'abc', 'avg_ratings': 4.5, 'awards': 'Hello', 'original_publish_year': 2010},
      { 'author': 'def', 'avg_ratings': 3.3, 'awards': 'Hello, Hello, Hello, Hello, Hello', 'original_publish_year': 2012}, 
      { 'author': 'abc', 'avg_ratings': 3.8, 'awards': 'Hello, Hello, Hello, Hello', 'original_publish_year': 2010}, 
      { 'author': 'obc', 'avg_ratings': 2.8, 'awards': 'Hello, Hello, Hello', 'original_publish_year': 2012}])

    df['awards'] = df.awards.str.split(',', expand=False)
    df['award count'] = df['awards'].str.len()
    
    df['minmax_norm_ratings'] = 1 + (df['avg_ratings'] - df.avg_ratings.min()) / (df.avg_ratings.max()-df.avg_ratings.min()) *9

    df['avg_ratings_mean'] = 1 + (df['avg_ratings'] - df.avg_ratings.mean()) / (df.avg_ratings.max()-df.avg_ratings.min()) *9

    return df

preprocessing()
# Out:
#   author  avg_ratings                                   awards  \
# 0    abc          4.1                  [Hello,  Hello,  Hello]
# 1    def          2.5                          [Hello,  Hello]
# 2    abc          4.5                                  [Hello]
# 3    def          3.3  [Hello,  Hello,  Hello,  Hello,  Hello]
# 4    abc          3.8          [Hello,  Hello,  Hello,  Hello]
# 5    obc          2.8                  [Hello,  Hello,  Hello]
#
#    original_publish_year  award count  minmax_norm_ratings  avg_ratings_mean
# 0                   2010            3                 8.20              3.70
# 1                   2012            2                 1.00             -3.50
# 2                   2010            1                10.00              5.50
# 3                   2012            5                 4.60              0.10
# 4                   2010            4                 6.85              2.35
# 5                   2012            3                 2.35             -2.15

# %%
def analyse_highest_book(df, a):
    dp = df.groupby(df.original_publish_year).agg({'minmax_norm_ratings': np.mean})
    dp = dp.rename(columns={'minmax_norm_ratings': 'minmax_norm_ratings_mean'})
    author_group = df.loc[df['author'] == a]
    book_max_rating = author_group.iloc[author_group['minmax_norm_ratings'].argmax()]['title']
    print(dp)
    return book_max_rating

print(analyse_highest_book(preprocessing(), 'Robert Jordan'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7045d5137068> in <module>
#       7     return book_max_rating
#       8
# ----> 9 print(analyse_highest_book(preprocessing(), 'Robert Jordan'))
#
# <ipython-input-2-7045d5137068> in analyse_highest_book(df, a)
#       1 def analyse_highest_book(df, a):
# ----> 2     dp = df.groupby(df.original_publish_year).agg({'minmax_norm_ratings': np.mean})
#       3     dp = dp.rename(columns={'minmax_norm_ratings': 'minmax_norm_ratings_mean'})
#       4     author_group = df.loc[df['author'] == a]
#       5     book_max_rating = author_group.iloc[author_group['minmax_norm_ratings'].argmax()]['title']
#
# ~/opt/anaconda3/envs/machine_learning/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'original_publish_year'
