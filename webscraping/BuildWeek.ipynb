# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt 
import numpy as np
import re 

page = requests.get("https://www.goodreads.com/list/show/50.The_Best_Epic_Fantasy_fiction_")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
def my_strip(i):
    a = 0
    for a in range(0,len(i),1):
        i[a] = i[a].string
    return i

# %%
#1 page



url = soup.select("a.bookTitle[href]") 
titles = soup.select(".bookTitle span")
author = soup.select(".authorName span")
#rating = soup.select("span.minirating")
rating = soup.select("span")
    #to split
    #num_ratings
    # avg_rating


# Page 2

# num_pages 
# num_reviews
# # publish_year
# series
# genres
# awards
# places
# titles 
rating
# Out:
# an>
#  <a data-text-id="1035762621533620974" href="#" onclick="swapContent($(this));; return false;">...more</a>
#  </span>,
#  <span id="freeTextContainer1035762621533620974"><b>A Game of Thrones (A Song of Ice and Fire, #1), George R.R. Martin</b> <br><br>A Game of Thrones is the first novel in A Song of Ice and Fire, a series of fantasy novels by American author George R. R. Martin. It was first published on August 1, 1996. The novel won the 1997 Locus Award and was nominated for both the 1997 Nebula Award and the 1997 World Fantasy Award. The novella Blood of the Dragon, comprising the Daenerys Targaryen chapters from the novel, won the 1997 Hugo Award for Best Novella. In Janua</br></br></span>,
# ...

# %%
print(my_strip(rating))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
page = requests.get("https://www.goodreads.com/book/show/13496.A_Game_of_Thrones")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
num_pages = soup.select(".darkGreyText span") #num_pages[1].text
num_reviews = soup.select("a.gr_hyperlink")
# publish_year
# series
# genres
# awards
# places
# titles 
#location = soup.select("div.infoBoxRowItem a")
#num_pages

num_pages[1].text
# Out:
# '835 pages'

# %%
for item in titles:
    print(item.text)
# Out:
# A Game of Thrones (A Song of Ice and Fire, #1)
#
#
# J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings
#
#
# The Name of the Wind (The Kingkiller Chronicle, #1)
#
#
# The Way of Kings (The Stormlight Archive, #1)
#
#
# The Chronicles of Narnia (Chronicles of Narnia, #1-7)
#
#
# The Eye of the World (The Wheel of Time, #1)
#
#
# The Final Empire (Mistborn, #1)
#
#
# His Dark Materials (His Dark Materials #1-3)
#
#
# Eragon (The Inheritance Cycle, #1)
#
#
# Assassin's Apprentice (Farseer Trilogy, #1)
#
#
# The Lies of Locke Lamora (Gentleman Bastard, #1)
#
#
# The Gunslinger
#
#
# Wizard's First Rule (Sword of Truth, #1)
#
#
# The Blade Itself (The First Law, #1)
#
#
# The Silmarillion
#
#
# Gardens of the Moon (Malazan Book of the Fallen, #1)
#
#
# The Princess Bride
#
#
# The Belgariad Boxed Set: Pawn of Prophecy / Queen of Sorcery / Magician's Gambit / Castle of Wizardry / Enchanters' End Game (The Belgariad, #1-5)
#
#
# A Wizard of Earthsea (Earthsea Cycle, #1)
# ...
