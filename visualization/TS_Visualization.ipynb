# %%
import pandas as pd
import numpy as np

def preprocessing():
    df = pd.read_csv("example.csv")
    
    # Calculating number of awards
    df['Awards'] = df['Awards'].str.strip('[]')
    df['Awards'] = df['Awards'].replace(r'^\s*$', np.NaN, regex=True)
    df['Awards_x'] = df.Awards.str.split(',')
    df['award_count'] = df['Awards_x'].str.len()
    df['award_count'] = df['award_count'].fillna(0)
    df['award_count'] = df['award_count'].astype(int)
    df = df.drop(['Awards_x'], axis= 1)
    
    # Cleaning author column from paranthesis text
    df['author'] = df.author.str.replace(r"\(.*Goodreads Author\)","")

    # cleaning number of ratings
    df['number of ratings'] = df['number of ratings'].str.replace('[,]',"")
    df['number of ratings'] = df['number of ratings'].astype(int)
    
    # cleaning avg_rat
    #df['avg_rat'] = df.avg_rat.str.replace('[^0-9.]',"")
    
    # cleaning Genre
    df['Genre'] = df['Genre'].str.strip('[]')
    #df['Genre'] = df['Genre'].replace('[,]', '')
    
    # Cleaning pages column from text
    df['Num_pages'] = df.Num_pages.str.replace('[^0-9]',"")
    df['Num_pages'] = df['Num_pages'].replace(r'^\s*$', np.NaN, regex=True)
    df['Num_pages'] = pd.to_numeric(df['Num_pages'])
    
    # Cleaning publish year
    df['Publishdate'] = df.Publishdate.str.replace('[^0-9]',"")
    df['Publishdate'] = df['Publishdate'].replace(r'^\s*$', np.NaN, regex=True)
    df['original_publish_year'] = df['Publishdate'].str[-4:]
    df = df.drop(['Publishdate'], axis= 1)

    # Calculating normalized ratings
    df['minmax_norm_ratings'] = 1 + (df['avg_rat'] - df.avg_rat.min()) / (df.avg_rat.max()-df.avg_rat.min()) *9
    df['mean_norm_ratings'] = 1 + (df['avg_rat'] - df.avg_rat.mean()) / (df.avg_rat.max()-df.avg_rat.min()) *9
    
    return df

preprocessing()
# Out:
#                                                 name                author  \
# 0     A Game of Thrones (A Song of Ice and Fire, #1)    George R.R. Martin
# 1    J.R.R. Tolkien 4-Book Boxed Set: The Hobbit ...        J.R.R. Tolkien
# 2    The Name of the Wind (The Kingkiller Chronic...     Patrick Rothfuss
# 3      The Way of Kings (The Stormlight Archive, #1)    Brandon Sanderson
# 4    The Chronicles of Narnia (Chronicles of Narn...            C.S. Lewis
# 5       The Eye of the World (The Wheel of Time, #1)         Robert Jordan
# 6                    The Final Empire (Mistborn, #1)    Brandon Sanderson
# 7       His Dark Materials (His Dark Materials #1-3)        Philip Pullman
# 8                 Eragon (The Inheritance Cycle, #1)  Christopher Paolini
# 9        Assassin's Apprentice (Farseer Trilogy, #1)           Robin Hobb
#
#    number of ratings                                                url  \
# 0            2046885  https://www.goodreads.com//book/show/13496.A_G...
# 1             112425  https://www.goodreads.com//book/show/30.J_R_R_...
# 2             739299  https://www.goodreads.com//book/show/186074.Th...
# 3             319614  https://www.goodreads.com//book/show/7235533-t...
# 4             532855  https://www.goodreads.com//book/show/11127.The...
# 5             402524  https://www.goodreads.com//book/show/228665.Th...
# 6             419345  https://www.goodreads.com//book/show/68428.The...
# 7             147381  https://www.goodreads.com//book/show/18116.His...
# 8            1470169  https://www.goodreads.com//book/show/113436.Er...
# 9             242007  https://www.goodreads.com//book/show/77197.Ass...
#
#    avg_rat  Num_pages                                             Awards  \
# 0     4.45      835.0  'Nebula Award Nominee for Best Novel (1997)', ...
# 1     4.60        NaN                                                NaN
# 2     4.52      662.0  'Locus Award Nominee for Best First Novel and ...
# 3     4.62     1007.0  'Locus Award Nominee for Best Fantasy Novel (2...
# 4     4.26        NaN                                                NaN
# 5     4.17      814.0  'Locus Award Nominee for Best Fantasy Book (19...
# 6     4.44      544.0  'Tähtifantasia Award Nominee (2018)', 'Prix El...
# 7     4.25     1088.0  'Literaturpreis der Jury der jungen Leser for ...
# 8     3.91      503.0  "Book Sense Book of the Year Award for Childre...
# 9     4.15      435.0  'Locus Award Nominee for Fantasy (1996)', 'Bri...
#
#                                                Genre  award_count  \
# 0  'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            4
# 1  'Fantasy', 'Fiction', 'Classics', 'Adventure',...            0
# 2  'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            8
# 3  'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            4
# 4  'Fantasy', 'Classics', 'Fiction', 'Young Adult...            0
# 5  'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            1
# 6  'Fantasy', 'Fiction', 'Fantasy', 'High Fantasy...            2
# 7  'Fantasy', 'Young Adult', 'Fiction', 'Children...            1
# 8  'Fantasy', 'Young Adult', 'Fiction', 'Fantasy'...           20
# 9  'Fantasy', 'Fiction', 'Fantasy', 'Epic Fantasy...            3
#
#   original_publish_year  minmax_norm_ratings  mean_norm_ratings
# 0                  1996             7.845070           2.432394
# 1                  1955             9.746479           4.333803
# 2                  2007             8.732394           3.319718
# 3                   NaN            10.000000           4.587324
# 4                  1956             5.436620           0.023944
# 5                  1990             4.295775          -1.116901
# 6                  2006             7.718310           2.305634
# 7                  2000             5.309859          -0.102817
# 8                  2002             1.000000          -4.412676
# 9                  1995             4.042254          -1.370423

# %%
import matplotlib

# %%
# calculate correlation between pages and number of ratings

column_1 = preprocessing()["Num_pages"]
column_2 = preprocessing()["number of ratings"]
correlation = column_1.corr(column_2) 
print(correlation)
# Out:
# -0.15654584086705647

# %%
# Visualize the awards distribution in a boxplot and aggregtated bars. 
#Decide which of these representations gives us more information and in which cases they should be used.
